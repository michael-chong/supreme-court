# %%
# if you are havign difficulty downloading numpy or scipy (requirements for sklearn), 
# https://scikit-learn.org/stable/modules/tree.html
from sklearn import tree
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# load data cleaned from rscript
sc_df = pd.read_csv('sc_decisions_final.csv')
sc_df.head()
# Out:
#    Unnamed: 0    c_chief  c_lcDisagreement c_lcDispositionDirection  \
# 0           1  Rehnquist               0.0             Conservative
# 1           2  Rehnquist               0.0             Conservative
# 2           3  Rehnquist               0.0             Conservative
# 3           4  Rehnquist               0.0             Conservative
# 4           5  Rehnquist               0.0             Conservative
#
#       c_issueArea  c_adminActionBool  c_oralArgBool  c_reargBool  \
# 0  Judicial Power                  1              1            0
# 1  Judicial Power                  1              1            0
# 2  Judicial Power                  1              1            0
# 3  Judicial Power                  1              1            0
# 4  Judicial Power                  1              1            0
#
#   c_decisionTime  c_formerCourt  ... e_senateMajority  \
# 0    31-180 Days              0  ...       Republican
# 1    31-180 Days              1  ...       Republican
# 2    31-180 Days              0  ...       Republican
# 3    31-180 Days              1  ...       Republican
# 4    31-180 Days              1  ...       Republican
#
#   e_decisionPresidentParty e_JCApproval j_justiceDecisionAgeBand  \
# 0                 Democrat      Approve                      65+
# 1                 Democrat      Approve                      65+
# 2                 Democrat      Approve                      65+
# 3                 Democrat      Approve                     0-65
# 4                 Democrat      Approve                     0-65
#
#   j_justiceRegion j_justiceReligion j_justiceEthnicity  \
# 0         Midwest          Lutheran          Caucasian
# 1         Midwest        Protestant          Caucasian
# 2            West               NaN          Caucasian
# 3       Northeast       Catholicism          Caucasian
# 4            West       Catholicism          Caucasian
#
#   j_justicePresidentParty j_justiceVotesAppointed     direction
# 0              Republican                    <75%       Liberal
# 1              Republican                   >=75%       Liberal
# 2              Republican                   >=75%       Liberal
# 3              Republican                   >=75%  Conservative
# 4              Republican                   >=75%       Liberal
#
# [5 rows x 23 columns]

# %%
sc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14047 entries, 0 to 14046
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                14047 non-null  int64
#  1   c_chief                   14047 non-null  object
#  2   c_lcDisagreement          14029 non-null  float64
#  3   c_lcDispositionDirection  14047 non-null  object
#  4   c_issueArea               14047 non-null  object
#  5   c_adminActionBool         14047 non-null  int64
#  6   c_oralArgBool             14047 non-null  int64
#  7   c_reargBool               14047 non-null  int64
#  8   c_decisionTime            14047 non-null  object
#  9   c_formerCourt             14047 non-null  int64
#  10  c_caseOriginRegion        12676 non-null  object
#  11  c_caseOriginCourt         12676 non-null  object
#  12  e_houseMajority           14047 non-null  object
#  13  e_senateMajority          14047 non-null  object
#  14  e_decisionPresidentParty  14047 non-null  object
#  15  e_JCApproval              14047 non-null  object
#  16  j_justiceDecisionAgeBand  14047 non-null  object
#  17  j_justiceRegion           13976 non-null  object
#  18  j_justiceReligion         13536 non-null  object
#  19  j_justiceEthnicity        14047 non-null  object
#  20  j_justicePresidentParty   14047 non-null  object
#  21  j_justiceVotesAppointed   14047 non-null  object
#  22  direction                 14047 non-null  object
# dtypes: float64(1), int64(5), object(17)
# memory usage: 2.5+ MB

# %%
# fill missing values as they are legitimate
sc_df = sc_df.fillna("N/A")

# %%
# select explanatory and response variables
X = sc_df.loc[:, sc_df.columns != 'direction']
y = sc_df[['direction']]

# %%
# split into training and testing
X_train, X_test, y_train, y_test = train_test_split(X , y, test_size = 0.25, random_state = 42)
print("Training split input- ", X_train.shape)
print("Testing split input- ", X_test.shape)
# Out:
# Training split input-  (10535, 22)
# Testing split input-  (3512, 22)
